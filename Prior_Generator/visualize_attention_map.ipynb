# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from einops import rearrange
import cv2
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

from datasets.transforms import DataTransforms
from constants import *
from datasets.data_module import DataModule
from datasets.pretrain_dataset import (MultimodalPretrainingDataset, 
                                            multimodal_collate_fn)
from models.mgca.mgca_module import MGCA
from tqdm import tqdm
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
# Load pretrained model
ckpt_path = "./pretrained/vit_base.ckpt"
model = MGCA.load_from_checkpoint(ckpt_path, strict=False)
save_list=[]

# %%
# define datamodule
datamodule = DataModule(MultimodalPretrainingDataset, multimodal_collate_fn,
                        DataTransforms, 1, 1, 0)

# %%
for index, batch in enumerate(tqdm(datamodule.val_dataloader(),desc='Have been Generated')):
    with torch.no_grad():
        # print(batch['path'][0])
        # print(batch['entity_position_index'])
        _, patch_feat_q = model.img_encoder_q(batch["imgs"])
        patch_emb_q = model.img_encoder_q.local_embed(patch_feat_q)
        patch_emb_q = F.normalize(patch_emb_q, dim=-1)
        report_feat_q, word_feat_q, word_attn_q, sents = model.text_encoder_q(batch["caption_ids"].unsqueeze(0), batch["attention_mask"].unsqueeze(0), batch["token_type_ids"].unsqueeze(0))
        word_emb_q = model.text_encoder_q.local_embed(word_feat_q)
        word_emb_q = F.normalize(word_emb_q, dim=-1)
        bz = patch_feat_q.size(0)
        _, word_atten= model.word_local_atten_layer(word_emb_q, patch_emb_q, patch_emb_q)
        # print(batch['entity_position_index'])
        RadGraph_entity_atten=word_atten[:,:,:]
      
        # print(" ".join([x for x in sents[0] if x != "[PAD]"]))
        # sum_last_dim = RadGraph_entity_atten.sum(dim=2)
        # print(sum_last_dim)
        img = (batch["imgs"].cpu().numpy() * 0.5 + 0.5).clip(0, 1)[0].transpose(1, 2, 0)
        img = (img * 255).astype(np.uint8)
        overlay=img.copy()
        print(RadGraph_entity_atten.shape)
        attention_map=RadGraph_entity_atten.sum(dim=1)
        Interval_length=attention_map.max()-attention_map.min()
        attention_map=(attention_map-attention_map.min())/Interval_length
        atten_map = rearrange(attention_map, "b (p1 p2) -> b p1 p2", p1=14, p2=14).squeeze()
        pathology_aware_prior=atten_map.cpu().numpy().astype(np.float16)
       
        save_list.append({batch['path'][0]:pathology_aware_prior*5})
        if index%1000==0:
           print(batch['entity_position_index'])
           
           print(" ".join([x for x in sents[0] if x != "[PAD]"]))
           atten_map = ((atten_map.detach().cpu().numpy())*255).astype(np.uint8)
           atten_map = cv2.resize(atten_map, (224, 224), interpolation=cv2.INTER_CUBIC)
           attention_colormap = cv2.applyColorMap(atten_map, cv2.COLORMAP_JET)
           for i in range(14):
                for j in range(14):
                  top_left_x = j * 16
                  top_left_y = i * 16
                  bottom_right_x = (j + 1) *16
                  bottom_right_y = (i + 1) *16
                  color = attention_colormap[top_left_y, top_left_x].tolist()
                  cv2.rectangle(overlay, (top_left_x, top_left_y), (bottom_right_x, bottom_right_y), color, -1)
           img_with_heatmap = cv2.addWeighted(overlay, 0.5, img, 0.5, 0)
           img_with_heatmap = cv2.cvtColor(img_with_heatmap, cv2.COLOR_BGR2RGB)
           fig = plt.figure(figsize=(12, 6))  
           gs = fig.add_gridspec(2, 2, height_ratios=[4, 1]) 
           ax1 = fig.add_subplot(gs[0, 0])  
           ax2 = fig.add_subplot(gs[0, 1])  
           ax1.imshow(img)
           ax1.set_title("Original Image", fontsize=12)
           ax1.axis('off')
           ax2.imshow(img_with_heatmap)
           ax2.set_title("Image with Attention Heatmap", fontsize=12)
           ax2.axis('off')
           ax_text = fig.add_subplot(gs[1, :])  # 占用全部列
           ax_text.text(0.5, 0.5, 
             "Visualization Example", 
             ha='center', va='center', fontsize=14)
           ax_text.axis('off')
           plt.tight_layout()
           plt.show()
result_np=np.asarray(save_list)
np.save('pathology_aware_prior.npy',result_np)
print('finished')
# Out:
# Have been Generated:   0%|          | 0/2000 [00:00<?, ?it/s]
# torch.Size([1, 42, 196])
# tensor([ 6,  7,  8, 13, 18, 19, 20, 21, 22, 23, 28, 29, 31, 32, 33, 34, 35, 36,
#         38, 39, 43, 44, 46, 48, 52, 53, 55, 56, 57, 58, 59, 60, 61, 62, 65, 66,
#         67, 69, 70, 75, 76, 77])
# [CLS] there is no focal consolidation pleural effusion or pneumothorax bilateral nodular opacities that most likely represent nipple shadows the cardiomediastinal silhouette is normal clips project over the left lung potentially within the breast the imaged upper abdomen is unremarkable chronic deformity of the posterior left sixth and seventh ribs are noted no acute cardio pulmonary process [SEP]
# Have been Generated:   0%|          | 2/2000 [00:00<10:41,  3.11it/s]
# torch.Size([1, 34, 196])
# Have been Generated:   0%|          | 3/2000 [00:00<09:39,  3.45it/s]
# torch.Size([1, 38, 196])
# Have been Generated:   0%|          | 4/2000 [00:01<08:41,  3.83it/s]
# torch.Size([1, 38, 196])
# Have been Generated:   0%|          | 5/2000 [00:01<08:20,  3.99it/s]
# torch.Size([1, 30, 196])
# Have been Generated:   0%|          | 6/2000 [00:01<08:07,  4.09it/s]
# torch.Size([1, 64, 196])
# Have been Generated:   0%|          | 7/2000 [00:01<08:02,  4.13it/s]
# torch.Size([1, 32, 196])
# Have been Generated:   0%|          | 8/2000 [00:02<08:02,  4.12it/s]
# torch.Size([1, 41, 196])
# Have been Generated:   0%|          | 9/2000 [00:02<07:48,  4.25it/s]
# torch.Size([1, 65, 196])
# Have been Generated:   1%|          | 11/2000 [00:02<07:23,  4.49it/s]
# torch.Size([1, 55, 196])
# torch.Size([1, 53, 196])
# Have been Generated:   1%|          | 12/2000 [00:02<07:25,  4.47it/s]
# torch.Size([1, 67, 196])
# Have been Generated:   1%|          | 13/2000 [00:03<07:32,  4.39it/s]
# torch.Size([1, 72, 196])
# Have been Generated:   1%|          | 14/2000 [00:03<07:17,  4.54it/s]
# torch.Size([1, 43, 196])
# Have been Generated:   1%|          | 15/2000 [00:03<07:27,  4.44it/s]
# torch.Size([1, 15, 196])
# Have been Generated:   1%|          | 16/2000 [00:03<07:36,  4.35it/s]
# torch.Size([1, 64, 196])
# Have been Generated:   1%|          | 17/2000 [00:04<07:39,  4.32it/s]
# torch.Size([1, 68, 196])
# Have been Generated:   1%|          | 18/2000 [00:04<08:13,  4.01it/s]
# torch.Size([1, 33, 196])
# Have been Generated:   1%|          | 19/2000 [00:04<08:44,  3.78it/s]
# torch.Size([1, 73, 196])
# Have been Generated:   4%|▍         | 75/2000 [00:19<08:21,  3.84it/s]
# torch.Size([1, 2, 196])
# Have been Generated:   4%|▍         | 76/2000 [00:19<08:12,  3.91it/s]
# torch.Size([1, 15, 196])
# Have been Generated:   4%|▍         | 77/2000 [00:19<08:03,  3.98it/s]
# torch.Size([1, 55, 196])
# Have been Generated:   4%|▍         | 78/2000 [00:20<07:50,  4.08it/s]
# torch.Size([1, 49, 196])
# Have been Generated:   4%|▍         | 79/2000 [00:20<07:52,  4.07it/s]
# torch.Size([1, 27, 196])
# Have been Generated:   4%|▍         | 80/2000 [00:20<07:53,  4.06it/s]
# torch.Size([1, 16, 196])
# Have been Generated:   4%|▍         | 81/2000 [00:20<07:59,  4.00it/s]
# torch.Size([1, 57, 196])
# Have been Generated:   4%|▍         | 82/2000 [00:21<07:59,  4.00it/s]
# torch.Size([1, 48, 196])
# Have been Generated:   4%|▍         | 83/2000 [00:21<07:53,  4.04it/s]
# torch.Size([1, 33, 196])
# Have been Generated:   4%|▍         | 84/2000 [00:21<08:05,  3.94it/s]
# torch.Size([1, 27, 196])
# Have been Generated:   4%|▍         | 85/2000 [00:21<08:00,  3.98it/s]
# torch.Size([1, 39, 196])
# Have been Generated:   4%|▍         | 86/2000 [00:22<08:03,  3.95it/s]
# torch.Size([1, 53, 196])
# Have been Generated:   4%|▍         | 87/2000 [00:22<08:15,  3.86it/s]
# torch.Size([1, 53, 196])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 for index, batch in enumerate(tqdm(datamodule.val_dataloader(),desc='Have been Generated')):
#       2     with torch.no_grad():
#       3         # print(batch['path'][0])
#       4         # print(batch['entity_position_index'])
# ----> 5         _, patch_feat_q = model.img_encoder_q(batch["imgs"])
#       6         patch_emb_q = model.img_encoder_q.local_embed(patch_feat_q)
#       7         patch_emb_q = F.normalize(patch_emb_q, dim=-1)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/MGCA/mgca/models/backbones/encoder.py:142, in ImageEncoder.forward(self, x, get_local)
#     140     return self.resnet_forward(x, get_local=get_local)
#     141 elif "vit" in self.model_name:
# --> 142     img_feat = self.vit_forward(x)
#     143     return img_feat[:, 0].contiguous(), img_feat[:, 1:].contiguous()
#
# File ~/MGCA/mgca/models/backbones/encoder.py:136, in ImageEncoder.vit_forward(self, x)
#     135 def vit_forward(self, x):
# --> 136     return self.model(x, register_blk=11)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/MGCA/mgca/models/backbones/vits.py:195, in VisionTransformer.forward(self, x, register_blk)
#     192 x = self.pos_drop(x)
#     194 for i, blk in enumerate(self.blocks):
# --> 195     x = blk(x, register_blk == i)
#     196 x = self.norm(x)
#     198 return x
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/MGCA/mgca/models/backbones/vits.py:107, in Block.forward(self, x, register_hook)
#     104 def forward(self, x, register_hook=False):
#     105     x = x + self.drop_path(self.attn(self.norm1(x),
#     106                            register_hook=register_hook))
# --> 107     x = x + self.drop_path(self.mlp(self.norm2(x)))
#     108     return x
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/MGCA/mgca/models/backbones/vits.py:28, in Mlp.forward(self, x)
#      27 def forward(self, x):
# ---> 28     x = self.fc1(x)
#      29     x = self.act(x)
#      30     x = self.drop(x)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
